# %%
import pandas as pd

# %%
#Conjunto de datos 
datos = {
    "usuario": ["Ana", "Luis", "Martha", "Carolina",
                "Sofia", "Pedro", "Elena", "Diego"],

    "edad": [22.35, 28, 40, 19, 31, 26, 45, 33],

    "ciudad": ["CDMX", "Monterrey", "Guadalajara", "Puebla",
                "Cancun", "Merida", "Tijuana", "Miami"],

    "compras_realizadass": [5, 12, 3, 29, 15, 5, 14, 30],

    "activo": [True, False, True, True,
                False, True, False, True],

    "fecha_registro": ["2026-01-18", "2024-02-17", "2025-06-12",
                        "2026-05-23", "2025-04-11", "2026-03-14",
                        "2025-12-12", "2026-11-11"]
}

# %%
df = pd.DataFrame(datos)

# %%
print(df)
# Out:
#     usuario   edad       ciudad  compras_realizadass  activo fecha_registro
# 0       Ana  22.35         CDMX                    5    True     2026-01-18
# 1      Luis  28.00    Monterrey                   12   False     2024-02-17
# 2    Martha  40.00  Guadalajara                    3    True     2025-06-12
# 3  Carolina  19.00       Puebla                   29    True     2026-05-23
# 4     Sofia  31.00       Cancun                   15   False     2025-04-11
# 5     Pedro  26.00       Merida                    5    True     2026-03-14
# 6     Elena  45.00      Tijuana                   14   False     2025-12-12
# 7     Diego  33.00        Miami                   30    True     2026-11-11

# %%
cantidad= 1000000

# %%
import random

# %%
nombres= ["Ana", "Luis", "Martha", "Carolina",
                "Sofia", "Pedro", "Elena", "Diego"],
ciudades= ["CDMX", "Monterrey", "Guadalajara", "Puebla",
                "Cancun", "Merida", "Tijuana", "Miami"],
categorias= ["Tecnologias", "Ropa", "Maquillaje", "Postres", "Videojuegos", "Deportes", "Calzado", "Hogar"]

# %%
#Creacion del DataFrame
dfMillon = pd.DataFrame ({
    "nombre" : [random.choice(nombres) for _ in range(cantidad)],
    "edad" : [random.randint(18,70) for _ in range(cantidad)],
    "salario" : [round(random.uniform(5000,50000),2) for _ in range(cantidad)],
    "activo" : [random.choice([True,False]) for _ in range(cantidad)],
    "categoria" : [random.choice(categorias) for _ in range(cantidad)],
    "ciudad" : [random.choice(ciudades) for _ in range(cantidad)],
    "anio_registro" : [random.randint(2020,2026) for _ in range(cantidad)]
})

# %%
dfMillon.shape
# Out:
# (1000000, 7)

# %%
dfMillon.dtypes
# Out:
# nombre            object
# edad               int64
# salario          float64
# activo              bool
# categoria            str
# ciudad            object
# anio_registro      int64
# dtype: object

# %%
dfMillon.memory_usage(deep=True)
# Out:
# Index                  132
# nombre           128000000
# edad               8000000
# salario            8000000
# activo             1000000
# categoria         64876949
# ciudad           128000000
# anio_registro      8000000
# dtype: int64

# %%
dfMillon.memory_usage(deep=True).sum() /1024**2
# Out:
# np.float64(329.85408878326416)
